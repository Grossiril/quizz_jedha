# %% [markdown]
# # Build a quiz - Part 2

# %% [markdown]
# Below is the code we wrote yesterday, that asks three questions to the user and allows up to 3 wrong answers :

# %%
nb_de_chances = 3

print("Voici notre quiz, tu as trois chances !")

if nb_de_chances > 0:
    question1= input("Combien de fois la France a gagné la coupe du monde ? ")
    while question1 != "2":
        nb_de_chances -= 1
        print("Dommage ! Il te reste {} chances".format(nb_de_chances))
        if nb_de_chances == 0:
            print("Oh non ! Tu as perdu le jeu...")
            break
        question1 = input("Combien de fois la France a gagné la coupe du monde ? ")

if nb_de_chances > 0:
    question2 = input("Quand a été fondé Apple ? ")
    while question2 != "1976":
        nb_de_chances -=1
        print("Dommage ! Il te reste {} chances".format(nb_de_chances))
        if nb_de_chances == 0:
            print("Oh non ! Tu as perdu le jeu...")
            break
        question2 = input("Quand a été fondé Apple ? ")


if nb_de_chances > 0:
    question3 = input("Qui a fondé SpaceX ? ")
    question3 = question3.lower()
    while question3 != "elon musk":
        nb_de_chances -=1
        print("Dommage ! Il te reste {} chances".format(nb_de_chances))
        if nb_de_chances == 0:
            print("Oh non ! Tu as perdu le jeu...")
            break
        question3 = input("Qui a fondé SpaceX ? ")
        question3 = question3.lower()

if nb_de_chances > 0:
    print("Bravo ! Tu as gagné le quiz !")

# %% [markdown]
# Let's refactor our quiz now that we know how to be dry.
#
# SPECs:
#
# * Your code should be DRY
# * You should use functions

# %%
import pandas as pd
question_table = [
    {"question"  : "what is the result of 3 * 2",
     "answer"    : "6",
     'type'      : "int"},
    {"question"  : "what is the age of Trump ?",
     "answer"    : "80",
     'type'      : "int"},
    {"question"  : "what is the name of main actor in Terminator ?",
    "answer"    : "Schwartzenegger",
    'type'      : "str"}
]
def is_numeric(s: str) -> bool:
    try:
        float(s)
        return True
    except ValueError:
        return False
    
df_quest = pd.DataFrame(question_table)
df_quest
df_quest["answer"].iloc[0]
answer="6"
is_numeric(answer)
# Out:
# True

# %%
# rework of Quizz 
import pandas as pd
 


question_table = [
    {"question"  : "what is the result of 3 * 2",
     "answer"    : "6",
     'type'      : "int"},
    {"question"  : "what is the age of Trump ?",
     "answer"    : "80",
     'type'      : "int"},
    {"question"  : "what is the name of main actor in Terminator ?",
    "answer"    : "Schwartzenegger",
    'type'      : "str"}
]


df_quest = pd.DataFrame(question_table)


class Quizz():
    def __init(self,df_quest,lives=3, nb_questions=3):
        self.questions = df_quest
        self.lives = lives
        self.nb_questions = nb_questions
         
        return





def ask_question(df_quest,i,j,lives):
    """
    Ask question nb i from df_quest dataframe 
    Args:
        df_quest ([DataFrame]): [2 columns : 'question' and 'answer' ]
        1 line per question
        i ([type]): [line i of DataFrame df_quest]
        j: number of question in the game
        lives : nb of lives remaining before question asked
    """
    print(f"Question {j} :")
    answer = int(input(df_quest['question'].iloc[i]) )
    print(f"Your answer: {answer}")
    if compare_answer(answer,df_quest['answer'].iloc[i],df_quest['type'].iloc[i]) :
        print("Good job! This is the right answer")
        ok=True
        return(lives)
    else:
        lives-=1
        print(f"Sorry, you have {lives} chances left")
        if lives==0:
            print("Too bad, you lost the game ")
            return(lives)

def is_numeric(s: str) -> bool:
    try:
        float(s)
        return True
    except ValueError:
        return False
def is_int(s: str) -> bool:
    return s.isdigit() or (s.startswith('-') and s[1:].isdigit())

def compare_answer(answer,target,type):
    """compare answer to target; handle char 
    return boolean True / False"""
    
       
    if is_numeric(target) :
        if is_int(target):
            return int(target) == int(answer)
        else:
            return float(target) == float(answer)
        
        #return isinstance(answer,(int,float)) and (answer == target)
    elif type=='str' :
        return (answer.lower() == target.lower())
        
                
# *****main :******* 
# Version branch dev_2_rebuild ; commit "B2_before tests" 

ok=False
lives = 3 # nb of lives 
n_quest = 3 # nb questions         
    
print(" ** Welcome to our quizz!")
print(f" ** You have {lives} lives. **") 
   

for i in range (n_quest):
    print(i,i+1,lives)
    lives = ask_question(df_quest,i,i+1,lives)
    if lives == 0 :
        print(" Ooooh you lost the game !! ")
        break 
    elif i==n_quest-1:
        print(f" Congratulations you won the game with {lives} remaining lives")   

if  lives ==0 :
    print(" Ooooh you lost the game !! ")
         
else:
    print(f" Congratulations you won the game with {lives} remaining lives")
#print(f"you completed the quizz with  {lives} lives left")
# Out:
#  ** Welcome to our quizz!
#  ** You have 3 lives. **
# Question 1 :
# Your answer: 6
# Sorry, you have 2 chances left
# Question 2 :
# Your answer: 80
# Sorry, you have 2 chances left
#  Congratulations you won the game with 3 remaining lives

# %%
compare_answer('6',6)
# Out:
# False
